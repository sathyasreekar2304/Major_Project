# %%
from keras.models import *
from keras.layers import *
from tensorflow.keras.optimizers import *
from keras.preprocessing.image import *
import matplotlib.pyplot as plt

# %%
data_dir="data/"
Dis = []
for file in os.listdir(data_dir):
    Dis += [file]
print(Dis)
print(len(Dis))
# Out:
# ['Benign', 'Early', 'Pre', 'Pro']
# 4

# %%
img_height,img_width=128,128
batch_size=20

# %%
train_datagen = ImageDataGenerator(rescale=1./255,validation_split=0.3)
train_generator = train_datagen.flow_from_directory(data_dir,
                                                    target_size=(
                                                        img_height, img_width),
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    subset='training')
test_generator = train_datagen.flow_from_directory(data_dir,
                                                   target_size=(
                                                       img_height, img_width),
                                                   batch_size=batch_size,
                                                   class_mode='categorical',
                                                   subset='training')
# Out:
# Found 2281 images belonging to 4 classes.
# Found 2281 images belonging to 4 classes.

# %%
classifier = Sequential()

classifier.add(Convolution2D(512, (3, 3), input_shape=(128, 128, 3), activation='relu',strides=(3,3)))

classifier.add(MaxPooling2D(pool_size=(3, 3)))

classifier.add(Convolution2D(256, (2, 2), activation='relu'))

classifier.add(MaxPooling2D(pool_size=(1, 1)))

classifier.add(Flatten())

classifier.add(Dense(units=64, activation='relu'))

classifier.add(Dense(units=4, activation='softmax'))

classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history=classifier.fit(train_generator,epochs = 25,validation_data = test_generator,verbose = 1)

classifier.save("models/CNN_1.h5")
# Out:
# Epoch 1/25
# 115/115 [==============================] - 45s 385ms/step - loss: 1.0710 - accuracy: 0.5309 - val_loss: 0.5101 - val_accuracy: 0.7830
# Epoch 2/25
# 115/115 [==============================] - 41s 356ms/step - loss: 0.4502 - accuracy: 0.8067 - val_loss: 0.4727 - val_accuracy: 0.7782
# Epoch 3/25
# 115/115 [==============================] - 41s 361ms/step - loss: 0.3512 - accuracy: 0.8452 - val_loss: 0.8650 - val_accuracy: 0.6795
# Epoch 4/25
# 115/115 [==============================] - 42s 365ms/step - loss: 0.3538 - accuracy: 0.8509 - val_loss: 0.2425 - val_accuracy: 0.8996
# Epoch 5/25
# 115/115 [==============================] - 42s 363ms/step - loss: 0.2686 - accuracy: 0.8908 - val_loss: 0.1985 - val_accuracy: 0.9250
# Epoch 6/25
# 115/115 [==============================] - 40s 349ms/step - loss: 0.2181 - accuracy: 0.9097 - val_loss: 0.1632 - val_accuracy: 0.9430
# Epoch 7/25
# 115/115 [==============================] - 41s 358ms/step - loss: 0.1695 - accuracy: 0.9307 - val_loss: 0.1858 - val_accuracy: 0.9093
# Epoch 8/25
# 115/115 [==============================] - 41s 353ms/step - loss: 0.1634 - accuracy: 0.9347 - val_loss: 0.1583 - val_accuracy: 0.9259
# Epoch 9/25
# 115/115 [==============================] - 41s 355ms/step - loss: 0.1681 - accuracy: 0.9303 - val_loss: 0.1325 - val_accuracy: 0.9588
# Epoch 10/25
# 115/115 [==============================] - 42s 368ms/step - loss: 0.1465 - accuracy: 0.9443 - val_loss: 0.1622 - val_accuracy: 0.9290
# Epoch 11/25
# 115/115 [==============================] - 42s 368ms/step - loss: 0.1517 - accuracy: 0.9395 - val_loss: 0.1735 - val_accuracy: 0.9281
# Epoch 12/25
# 115/115 [==============================] - 43s 371ms/step - loss: 0.0922 - accuracy: 0.9645 - val_loss: 0.0617 - val_accuracy: 0.9776
# Epoch 13/25
# 115/115 [==============================] - 45s 388ms/step - loss: 0.1849 - accuracy: 0.9334 - val_loss: 0.0762 - val_accuracy: 0.9768
# Epoch 14/25
# 115/115 [==============================] - 40s 350ms/step - loss: 0.1130 - accuracy: 0.9540 - val_loss: 0.1193 - val_accuracy: 0.9500
# Epoch 15/25
# 115/115 [==============================] - 41s 353ms/step - loss: 0.0718 - accuracy: 0.9768 - val_loss: 0.0374 - val_accuracy: 0.9899
# Epoch 16/25
# 115/115 [==============================] - 41s 353ms/step - loss: 0.0482 - accuracy: 0.9864 - val_loss: 0.0360 - val_accuracy: 0.9899
# Epoch 17/25
# 115/115 [==============================] - 41s 359ms/step - loss: 0.0453 - accuracy: 0.9838 - val_loss: 0.0454 - val_accuracy: 0.9855
# Epoch 18/25
# 115/115 [==============================] - 41s 354ms/step - loss: 0.0372 - accuracy: 0.9908 - val_loss: 0.0211 - val_accuracy: 0.9952
# Epoch 19/25
# 115/115 [==============================] - 41s 355ms/step - loss: 0.0788 - accuracy: 0.9733 - val_loss: 0.1421 - val_accuracy: 0.9527
# Epoch 20/25
# 115/115 [==============================] - 42s 367ms/step - loss: 0.0614 - accuracy: 0.9798 - val_loss: 0.0200 - val_accuracy: 0.9965
# Epoch 21/25
# 115/115 [==============================] - 42s 362ms/step - loss: 0.0260 - accuracy: 0.9917 - val_loss: 0.0184 - val_accuracy: 0.9978
# Epoch 22/25
# 115/115 [==============================] - 41s 360ms/step - loss: 0.0165 - accuracy: 0.9965 - val_loss: 0.0079 - val_accuracy: 0.9996
# Epoch 23/25
# 115/115 [==============================] - 41s 360ms/step - loss: 0.0105 - accuracy: 0.9982 - val_loss: 0.0068 - val_accuracy: 0.9991
# Epoch 24/25
# 115/115 [==============================] - 41s 359ms/step - loss: 0.0082 - accuracy: 0.9987 - val_loss: 0.0059 - val_accuracy: 0.9996
# Epoch 25/25
# 115/115 [==============================] - 41s 360ms/step - loss: 0.0354 - accuracy: 0.9864 - val_loss: 0.0227 - val_accuracy: 0.9943

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(history.history['accuracy'],'r',label='Testing accuracy',color='green')
plt.plot(history.history['val_accuracy'],label='validation accuracy')
plt.xlabel('# Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig("models/cnn_acc.png")
plt.show()


plt.style.use("ggplot")
plt.figure()
plt.plot(history.history['loss'],'r',label='Testing losses',color='green')
plt.plot(history.history['val_loss'],label='validation losses')
plt.xlabel('# Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig("models/cnn_loss.png")
plt.show()


acc=history.history['accuracy'][-1]
print(acc)
# Out:
# C:\Users\ymts0585\AppData\Local\Temp\ipykernel_10008\2765264251.py:3: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r" (-> color=(1.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(history.history['accuracy'],'r',label='Testing accuracy',color='green')
# C:\Users\ymts0585\AppData\Local\Temp\ipykernel_10008\2765264251.py:14: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r" (-> color=(1.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(history.history['loss'],'r',label='Testing losses',color='green')
# 0.9864094853401184
